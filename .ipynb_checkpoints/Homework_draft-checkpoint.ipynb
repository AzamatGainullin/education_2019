# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://yandex.ru/search/?text=ситуация%20с%20газпромом&lr=213'
html = get_html(url)
soup = BeautifulSoup(html, 'lxml')
pages = soup.find_all('div')
spisok_slov = []
for i in pages:
    try:
        spisok_slov.append(i.text)
    except:
        pass

# %%
for i in spisok_slov:
    print(i)
# Out:
# Ya.Rum.sendRaf(183)НазадЯндекс Найти
# Ya.Rum.sendRaf(183)НазадЯндекс Найти
# НазадЯндекс Найти
# Назад
# Назад
# Назад
# Яндекс
#  Найти
#
# Найти
# Найти
#
# ПоискКартинкиВидеоКартыМаркетНовостиЭфирКоллекцииЗнатокиУслугиМузыкаПереводчикДискПочтаВсеЕщё
# ПоискКартинкиВидеоКартыМаркетНовостиЭфирКоллекцииЗнатокиУслугиМузыкаПереводчикДискПочтаВсеЕщё
# ПоискКартинкиВидеоКартыМаркетНовостиЭфирКоллекцииЗнатокиУслугиМузыкаПереводчикДискПочтаВсеЕщё
# Поиск
# Поиск
#
# Картинки
# Картинки
#
# Видео
# Видео
#
# Карты
# Карты
#
# Маркет
# Маркет
#
# Новости
# Новости
#
# Эфир
# Эфир
#
# Коллекции
# Коллекции
#
# Знатоки
# Знатоки
#
# Услуги
# Услуги
#
# Музыка
# Музыка
#
# Переводчик
# Переводчик
#
# Диск
# Диск
#
# Почта
# Почта
#
# Все
# Все
#
# Ещё
# Ещё
# .organic{position:relative}.organic_with-divider_yes .organic__subtitle+.organic__content-wrapper{margin-top:10px;padding-top:10px;border-top:1px solid rgba(0,0,0,.1)}.clearfix:after{display:block;clear:both;height:0;content:''}.organic__url{display:inline-block;overflow:hidden;max-width:100%;vertical-align:top;white-space:nowrap;text-overflow:ellipsis}.organic__url.link_cropped_no{overflow:visible;white-space:normal}.organic__url_type_multiline{display:inline;white-space:normal}.organic__url{margin:-10px -2px -2px -10px;padding:10px 2px 2px 10px}.organic__url_type_multiline .organic__url-text{display:inline}.organic__url_type_supertitle{font-size:28px;line-height:32px}.organic__url.link:not(.link_cropped_no) .organic__url-text{overflow:hidden;text-overflow:ellipsis}.utilityfocus.utilityfocus .organic__url.link_focused_yes{outline:0}.utilityfocus.utilityfocus .organic__url.link_focused_yes .organic__url-text{outline:2px solid #fc0}.organic__title-wrapper{font-weight:400;margin:0;padding:0;position:relative}.organic__path{display:inline-block;overflow:hidden;vertical-align:top;text-overflow:ellipsis;max-width:93%}.path{display:inline-block;white-space:nowrap;color:#070}.path_ellipsis{overflow:hidden;text-overflow:ellipsis;display:block}.path__item{outline:0}.path,.path__item{-webkit-font-smoothing:antialiased}.path__separator{font-family:Verdana;line-height:1;margin:0 .3em;-webkit-font-smoothing:auto}.path__item .favicon{position:relative;display:inline-block;left:0;margin-top:-2px;padding-right:5px}.path_show-https .path__item:first-child{background:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg") no-repeat -9999px -9999px}.path_show-https .path__item:first-child:before{display:inline-block;width:12px;height:12px;content:'';background:url("//yastatic.net/s3/web4static/_/0GtAd4cg0-2BWzpBEdT8k5LiYaQ.svg") no-repeat -1px 1px}.path_show-https .path__item:first-child:hover:before{background-image:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg")}.path_show-https [class].path__item_with-favicon:before{display:none}.organic__verified{margin-top:-2px;margin-bottom:-2px;margin-left:4px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0}.verified{line-height:1em}.verified,.verified-list{display:inline-block;white-space:nowrap}.verified-list__wrapper{height:20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;overflow:hidden}.verified-list__item{margin-bottom:10px}.verified__text{margin-left:3px;display:inline-block}.verified__icon{position:relative;top:-1px;display:inline-block;vertical-align:middle;width:20px;height:20px;background-repeat:no-repeat;background-position:center;background-size:contain}.verified .verified__link.verified__link_popup_yes{display:none}.verified__tooltip.verified__tooltip_view_default{max-width:265px}.verified__tooltip.verified__tooltip_view_default .tooltip__content{padding:10px 12px;font-size:13px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{display:table;opacity:.6}.verified__link_popup_yes.verified__link:hover,.verified__tooltip_view_default .link_theme_normal:hover{opacity:1}.verified__link_popup_yes.verified__link,.verified__link_popup_yes.verified__link:hover,.verified__link_popup_yes.verified__link:visited,.verified__tooltip_view_default .link_theme_normal,.verified__tooltip_view_default .link_theme_normal:hover,.verified__tooltip_view_default .link_theme_normal:visited{color:#fff}.verified-list{vertical-align:bottom}.verified__tooltip.verified__tooltip_view_default .tooltip__content{line-height:16px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{margin-top:2px}.verified__text{position:relative;z-index:-1;top:1px}.verified__icon_type_more120{background-image:url("//yastatic.net/s3/web4static/_/W_-LQC560ttBX-MCei9oML5gHJ4.svg")}.extralink ...
# .organic{position:relative}.organic_with-divider_yes .organic__subtitle+.organic__content-wrapper{margin-top:10px;padding-top:10px;border-top:1px solid rgba(0,0,0,.1)}.clearfix:after{display:block;clear:both;height:0;content:''}.organic__url{display:inline-block;overflow:hidden;max-width:100%;vertical-align:top;white-space:nowrap;text-overflow:ellipsis}.organic__url.link_cropped_no{overflow:visible;white-space:normal}.organic__url_type_multiline{display:inline;white-space:normal}.organic__url{margin:-10px -2px -2px -10px;padding:10px 2px 2px 10px}.organic__url_type_multiline .organic__url-text{display:inline}.organic__url_type_supertitle{font-size:28px;line-height:32px}.organic__url.link:not(.link_cropped_no) .organic__url-text{overflow:hidden;text-overflow:ellipsis}.utilityfocus.utilityfocus .organic__url.link_focused_yes{outline:0}.utilityfocus.utilityfocus .organic__url.link_focused_yes .organic__url-text{outline:2px solid #fc0}.organic__title-wrapper{font-weight:400;margin:0;padding:0;position:relative}.organic__path{display:inline-block;overflow:hidden;vertical-align:top;text-overflow:ellipsis;max-width:93%}.path{display:inline-block;white-space:nowrap;color:#070}.path_ellipsis{overflow:hidden;text-overflow:ellipsis;display:block}.path__item{outline:0}.path,.path__item{-webkit-font-smoothing:antialiased}.path__separator{font-family:Verdana;line-height:1;margin:0 .3em;-webkit-font-smoothing:auto}.path__item .favicon{position:relative;display:inline-block;left:0;margin-top:-2px;padding-right:5px}.path_show-https .path__item:first-child{background:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg") no-repeat -9999px -9999px}.path_show-https .path__item:first-child:before{display:inline-block;width:12px;height:12px;content:'';background:url("//yastatic.net/s3/web4static/_/0GtAd4cg0-2BWzpBEdT8k5LiYaQ.svg") no-repeat -1px 1px}.path_show-https .path__item:first-child:hover:before{background-image:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg")}.path_show-https [class].path__item_with-favicon:before{display:none}.organic__verified{margin-top:-2px;margin-bottom:-2px;margin-left:4px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0}.verified{line-height:1em}.verified,.verified-list{display:inline-block;white-space:nowrap}.verified-list__wrapper{height:20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;overflow:hidden}.verified-list__item{margin-bottom:10px}.verified__text{margin-left:3px;display:inline-block}.verified__icon{position:relative;top:-1px;display:inline-block;vertical-align:middle;width:20px;height:20px;background-repeat:no-repeat;background-position:center;background-size:contain}.verified .verified__link.verified__link_popup_yes{display:none}.verified__tooltip.verified__tooltip_view_default{max-width:265px}.verified__tooltip.verified__tooltip_view_default .tooltip__content{padding:10px 12px;font-size:13px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{display:table;opacity:.6}.verified__link_popup_yes.verified__link:hover,.verified__tooltip_view_default .link_theme_normal:hover{opacity:1}.verified__link_popup_yes.verified__link,.verified__link_popup_yes.verified__link:hover,.verified__link_popup_yes.verified__link:visited,.verified__tooltip_view_default .link_theme_normal,.verified__tooltip_view_default .link_theme_normal:hover,.verified__tooltip_view_default .link_theme_normal:visited{color:#fff}.verified-list{vertical-align:bottom}.verified__tooltip.verified__tooltip_view_default .tooltip__content{line-height:16px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{margin-top:2px}.verified__text{position:relative;z-index:-1;top:1px}.verified__icon_type_more120{background-image:url("//yastatic.net/s3/web4static/_/W_-LQC560ttBX-MCei9oML5gHJ4.svg")}.extralink ...
#
#
#
#
#
# .organic{position:relative}.organic_with-divider_yes .organic__subtitle+.organic__content-wrapper{margin-top:10px;padding-top:10px;border-top:1px solid rgba(0,0,0,.1)}.clearfix:after{display:block;clear:both;height:0;content:''}.organic__url{display:inline-block;overflow:hidden;max-width:100%;vertical-align:top;white-space:nowrap;text-overflow:ellipsis}.organic__url.link_cropped_no{overflow:visible;white-space:normal}.organic__url_type_multiline{display:inline;white-space:normal}.organic__url{margin:-10px -2px -2px -10px;padding:10px 2px 2px 10px}.organic__url_type_multiline .organic__url-text{display:inline}.organic__url_type_supertitle{font-size:28px;line-height:32px}.organic__url.link:not(.link_cropped_no) .organic__url-text{overflow:hidden;text-overflow:ellipsis}.utilityfocus.utilityfocus .organic__url.link_focused_yes{outline:0}.utilityfocus.utilityfocus .organic__url.link_focused_yes .organic__url-text{outline:2px solid #fc0}.organic__title-wrapper{font-weight:400;margin:0;padding:0;position:relative}.organic__path{display:inline-block;overflow:hidden;vertical-align:top;text-overflow:ellipsis;max-width:93%}.path{display:inline-block;white-space:nowrap;color:#070}.path_ellipsis{overflow:hidden;text-overflow:ellipsis;display:block}.path__item{outline:0}.path,.path__item{-webkit-font-smoothing:antialiased}.path__separator{font-family:Verdana;line-height:1;margin:0 .3em;-webkit-font-smoothing:auto}.path__item .favicon{position:relative;display:inline-block;left:0;margin-top:-2px;padding-right:5px}.path_show-https .path__item:first-child{background:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg") no-repeat -9999px -9999px}.path_show-https .path__item:first-child:before{display:inline-block;width:12px;height:12px;content:'';background:url("//yastatic.net/s3/web4static/_/0GtAd4cg0-2BWzpBEdT8k5LiYaQ.svg") no-repeat -1px 1px}.path_show-https .path__item:first-child:hover:before{background-image:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg")}.path_show-https [class].path__item_with-favicon:before{display:none}.organic__verified{margin-top:-2px;margin-bottom:-2px;margin-left:4px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0}.verified{line-height:1em}.verified,.verified-list{display:inline-block;white-space:nowrap}.verified-list__wrapper{height:20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;overflow:hidden}.verified-list__item{margin-bottom:10px}.verified__text{margin-left:3px;display:inline-block}.verified__icon{position:relative;top:-1px;display:inline-block;vertical-align:middle;width:20px;height:20px;background-repeat:no-repeat;background-position:center;background-size:contain}.verified .verified__link.verified__link_popup_yes{display:none}.verified__tooltip.verified__tooltip_view_default{max-width:265px}.verified__tooltip.verified__tooltip_view_default .tooltip__content{padding:10px 12px;font-size:13px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{display:table;opacity:.6}.verified__link_popup_yes.verified__link:hover,.verified__tooltip_view_default .link_theme_normal:hover{opacity:1}.verified__link_popup_yes.verified__link,.verified__link_popup_yes.verified__link:hover,.verified__link_popup_yes.verified__link:visited,.verified__tooltip_view_default .link_theme_normal,.verified__tooltip_view_default .link_theme_normal:hover,.verified__tooltip_view_default .link_theme_normal:visited{color:#fff}.verified-list{vertical-align:bottom}.verified__tooltip.verified__tooltip_view_default .tooltip__content{line-height:16px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{margin-top:2px}.verified__text{position:relative;z-index:-1;top:1px}.verified__icon_type_more120{background-image:url("//yastatic.net/s3/web4static/_/W_-LQC560ttBX-MCei9oML5gHJ4.svg")}.extralink ...
# .organic{position:relative}.organic_with-divider_yes .organic__subtitle+.organic__content-wrapper{margin-top:10px;padding-top:10px;border-top:1px solid rgba(0,0,0,.1)}.clearfix:after{display:block;clear:both;height:0;content:''}.organic__url{display:inline-block;overflow:hidden;max-width:100%;vertical-align:top;white-space:nowrap;text-overflow:ellipsis}.organic__url.link_cropped_no{overflow:visible;white-space:normal}.organic__url_type_multiline{display:inline;white-space:normal}.organic__url{margin:-10px -2px -2px -10px;padding:10px 2px 2px 10px}.organic__url_type_multiline .organic__url-text{display:inline}.organic__url_type_supertitle{font-size:28px;line-height:32px}.organic__url.link:not(.link_cropped_no) .organic__url-text{overflow:hidden;text-overflow:ellipsis}.utilityfocus.utilityfocus .organic__url.link_focused_yes{outline:0}.utilityfocus.utilityfocus .organic__url.link_focused_yes .organic__url-text{outline:2px solid #fc0}.organic__title-wrapper{font-weight:400;margin:0;padding:0;position:relative}.organic__path{display:inline-block;overflow:hidden;vertical-align:top;text-overflow:ellipsis;max-width:93%}.path{display:inline-block;white-space:nowrap;color:#070}.path_ellipsis{overflow:hidden;text-overflow:ellipsis;display:block}.path__item{outline:0}.path,.path__item{-webkit-font-smoothing:antialiased}.path__separator{font-family:Verdana;line-height:1;margin:0 .3em;-webkit-font-smoothing:auto}.path__item .favicon{position:relative;display:inline-block;left:0;margin-top:-2px;padding-right:5px}.path_show-https .path__item:first-child{background:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg") no-repeat -9999px -9999px}.path_show-https .path__item:first-child:before{display:inline-block;width:12px;height:12px;content:'';background:url("//yastatic.net/s3/web4static/_/0GtAd4cg0-2BWzpBEdT8k5LiYaQ.svg") no-repeat -1px 1px}.path_show-https .path__item:first-child:hover:before{background-image:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg")}.path_show-https [class].path__item_with-favicon:before{display:none}.organic__verified{margin-top:-2px;margin-bottom:-2px;margin-left:4px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0}.verified{line-height:1em}.verified,.verified-list{display:inline-block;white-space:nowrap}.verified-list__wrapper{height:20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;overflow:hidden}.verified-list__item{margin-bottom:10px}.verified__text{margin-left:3px;display:inline-block}.verified__icon{position:relative;top:-1px;display:inline-block;vertical-align:middle;width:20px;height:20px;background-repeat:no-repeat;background-position:center;background-size:contain}.verified .verified__link.verified__link_popup_yes{display:none}.verified__tooltip.verified__tooltip_view_default{max-width:265px}.verified__tooltip.verified__tooltip_view_default .tooltip__content{padding:10px 12px;font-size:13px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{display:table;opacity:.6}.verified__link_popup_yes.verified__link:hover,.verified__tooltip_view_default .link_theme_normal:hover{opacity:1}.verified__link_popup_yes.verified__link,.verified__link_popup_yes.verified__link:hover,.verified__link_popup_yes.verified__link:visited,.verified__tooltip_view_default .link_theme_normal,.verified__tooltip_view_default .link_theme_normal:hover,.verified__tooltip_view_default .link_theme_normal:visited{color:#fff}.verified-list{vertical-align:bottom}.verified__tooltip.verified__tooltip_view_default .tooltip__content{line-height:16px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{margin-top:2px}.verified__text{position:relative;z-index:-1;top:1px}.verified__icon_type_more120{background-image:url("//yastatic.net/s3/web4static/_/W_-LQC560ttBX-MCei9oML5gHJ4.svg")}.extralink ...
# .organic{position:relative}.organic_with-divider_yes .organic__subtitle+.organic__content-wrapper{margin-top:10px;padding-top:10px;border-top:1px solid rgba(0,0,0,.1)}.clearfix:after{display:block;clear:both;height:0;content:''}.organic__url{display:inline-block;overflow:hidden;max-width:100%;vertical-align:top;white-space:nowrap;text-overflow:ellipsis}.organic__url.link_cropped_no{overflow:visible;white-space:normal}.organic__url_type_multiline{display:inline;white-space:normal}.organic__url{margin:-10px -2px -2px -10px;padding:10px 2px 2px 10px}.organic__url_type_multiline .organic__url-text{display:inline}.organic__url_type_supertitle{font-size:28px;line-height:32px}.organic__url.link:not(.link_cropped_no) .organic__url-text{overflow:hidden;text-overflow:ellipsis}.utilityfocus.utilityfocus .organic__url.link_focused_yes{outline:0}.utilityfocus.utilityfocus .organic__url.link_focused_yes .organic__url-text{outline:2px solid #fc0}.organic__title-wrapper{font-weight:400;margin:0;padding:0;position:relative}.organic__path{display:inline-block;overflow:hidden;vertical-align:top;text-overflow:ellipsis;max-width:93%}.path{display:inline-block;white-space:nowrap;color:#070}.path_ellipsis{overflow:hidden;text-overflow:ellipsis;display:block}.path__item{outline:0}.path,.path__item{-webkit-font-smoothing:antialiased}.path__separator{font-family:Verdana;line-height:1;margin:0 .3em;-webkit-font-smoothing:auto}.path__item .favicon{position:relative;display:inline-block;left:0;margin-top:-2px;padding-right:5px}.path_show-https .path__item:first-child{background:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg") no-repeat -9999px -9999px}.path_show-https .path__item:first-child:before{display:inline-block;width:12px;height:12px;content:'';background:url("//yastatic.net/s3/web4static/_/0GtAd4cg0-2BWzpBEdT8k5LiYaQ.svg") no-repeat -1px 1px}.path_show-https .path__item:first-child:hover:before{background-image:url("//yastatic.net/s3/web4static/_/v7Avwy65TUiwFF27BEEFN762tNo.svg")}.path_show-https [class].path__item_with-favicon:before{display:none}.organic__verified{margin-top:-2px;margin-bottom:-2px;margin-left:4px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0}.verified{line-height:1em}.verified,.verified-list{display:inline-block;white-space:nowrap}.verified-list__wrapper{height:20px;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;overflow:hidden}.verified-list__item{margin-bottom:10px}.verified__text{margin-left:3px;display:inline-block}.verified__icon{position:relative;top:-1px;display:inline-block;vertical-align:middle;width:20px;height:20px;background-repeat:no-repeat;background-position:center;background-size:contain}.verified .verified__link.verified__link_popup_yes{display:none}.verified__tooltip.verified__tooltip_view_default{max-width:265px}.verified__tooltip.verified__tooltip_view_default .tooltip__content{padding:10px 12px;font-size:13px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{display:table;opacity:.6}.verified__link_popup_yes.verified__link:hover,.verified__tooltip_view_default .link_theme_normal:hover{opacity:1}.verified__link_popup_yes.verified__link,.verified__link_popup_yes.verified__link:hover,.verified__link_popup_yes.verified__link:visited,.verified__tooltip_view_default .link_theme_normal,.verified__tooltip_view_default .link_theme_normal:hover,.verified__tooltip_view_default .link_theme_normal:visited{color:#fff}.verified-list{vertical-align:bottom}.verified__tooltip.verified__tooltip_view_default .tooltip__content{line-height:16px}.verified__link_popup_yes.verified__link,.verified__tooltip_view_default .link_theme_normal{margin-top:2px}.verified__text{position:relative;z-index:-1;top:1px}.verified__icon_type_more120{background-image:url("//yastatic.net/s3/web4static/_/W_-LQC560ttBX-MCei9oML5gHJ4.svg")}.extralink ...
# 1«Газпром» ищет способы избежать крушения?versia.ru›gazprom-ishhet-sposoby…krusheniyaСохранённая копияПожаловатьсяИнформация о сайте Подробнее о сайтеТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и... Читать ещёТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные трубопроводные проекты. В нынешнем году этот процесс ускорится. ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и доводят до плановых показателей сразу два крупнейших терминала на Восточном побережье, ориентированном как раз на европейское направление. Скрыть
# 1«Газпром» ищет способы избежать крушения?versia.ru›gazprom-ishhet-sposoby…krusheniyaСохранённая копияПожаловатьсяИнформация о сайте Подробнее о сайтеТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и... Читать ещёТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные трубопроводные проекты. В нынешнем году этот процесс ускорится. ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и доводят до плановых показателей сразу два крупнейших терминала на Восточном побережье, ориентированном как раз на европейское направление. Скрыть
#
#
#
#
#
# 1«Газпром» ищет способы избежать крушения?versia.ru›gazprom-ishhet-sposoby…krusheniyaСохранённая копияПожаловатьсяИнформация о сайте Подробнее о сайтеТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и... Читать ещёТем временем «Газпром» всё активнее закатывает деньги в свои многочисленные трубопроводные проекты. В нынешнем году этот процесс ускорится. ... «Ситуация на газовом рынке Европы в 2018 году будет только обостряться, – прогнозирует аналитик Анатолий Несмиян. – В США вводят в строй и доводят до плановых показателей сразу два крупнейших терминала на Восточном побережье, ориентированном как раз на европейское направление. Скрыть
# 1
#
#
# «Газпром» ищет способы избежать крушения?
# versia.ru›gazprom-ishhet-sposoby…krusheniyaСохранённая копияПожаловатьсяИнформация о сайте Подробнее о сайте
# versia.ru›gazprom-ishhet-sposoby…krusheniya
# Сохранённая копияПожаловатьсяИнформация о сайте
# Сохранённая копияПожаловатьсяИнформация о сайте
#  Подробнее о сайте
#  Подробнее о сайте
#  Подробнее о сайте
# youtube.com
# youtube.com
# 2:112:11"Газпром": ситуация с отключениями может...youtube.com
# 2:112:11
#
#
#
#
# 2:11
# 2:11
#
# 2:11
#
# 2:11
# 2:11
# "Газпром": ситуация с отключениями может...
# "Газпром": ситуация с отключениями может...
# youtube.com
# youtube.com
# youtube.com
# 48:04HD48:04HD«Нафтогаз» против «Газпрома»: к чему...youtube.com
# 48:04HD48:04HD
#
#
#
#
# 48:04HD
# 48:04
# HD
#
# 48:04HD
#
# 48:04HD
# 48:04
# HD
# «Нафтогаз» против «Газпрома»: к чему...
# «Нафтогаз» против «Газпрома»: к чему...
# youtube.com
# youtube.com
# youtube.com
# 00:3500:35Спасибо «Газпрому»: Беглов о том, как...yandex.ru
# 00:3500:35
#
#
#
#
# 00:35
# 00:35
#
# 00:35
#
# 00:35
# 00:35
# Спасибо «Газпрому»: Беглов о том, как...
# Спасибо «Газпрому»: Беглов о том, как...
# yandex.ru
# yandex.ru
# yandex.ru
# 2:17HD2:17HDНафтогаз просит помощи у Киева из за проблем...youtube.com13:1013:10"Газпром" тревожит ситуация с оплатой...vesti.ru+ 4 тыс.Все видео
# 2:17HD2:17HDНафтогаз просит помощи у Киева из за проблем...youtube.com13:1013:10"Газпром" тревожит ситуация с оплатой...vesti.ru+ 4 тыс.Все видео
# 2:17HD2:17HDНафтогаз просит помощи у Киева из за проблем...youtube.com13:1013:10"Газпром" тревожит ситуация с оплатой...vesti.ru+ 4 тыс.Все видео
# 2:17HD2:17HDНафтогаз просит помощи у Киева из за проблем...youtube.com
# 2:17HD2:17HD
#
#
#
#
# 2:17HD
# 2:17
# HD
#
# 2:17HD
#
# 2:17HD
# 2:17
# HD
# Нафтогаз просит помощи у Киева из за проблем...
# Нафтогаз просит помощи у Киева из за проблем...
# youtube.com
# youtube.com
# youtube.com
# 13:1013:10"Газпром" тревожит ситуация с оплатой...vesti.ru
# 13:1013:10
#
#
#
#
# 13:10
# 13:10
#
# 13:10
#
# 13:10
# 13:10
# "Газпром" тревожит ситуация с оплатой...
# "Газпром" тревожит ситуация с оплатой...
# vesti.ru
# vesti.ru
# vesti.ru
# + 4 тыс.Все видео
# + 4 тыс.
#
#
#
#
# + 4 тыс.
#
# + 4 тыс.
# Все видео
#
#
#
# 5Газпром сегодня: свежие новости от Газпромnews.rambler.ru›organization/gazprom/ПожаловатьсяИнформация о сайте Подробнее о сайтеГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ... Читать ещёГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. Другое 5 часов назад. Беглов: реконструкция в Таврическом саду Петербурга может обойтись в 2-4 млрд рублей. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ польской. Другое 14 часов назад. ОСК и структуры «Газпрома» и «Газпром нефти» договорились о сотрудничестве. Скрыть
# 5Газпром сегодня: свежие новости от Газпромnews.rambler.ru›organization/gazprom/ПожаловатьсяИнформация о сайте Подробнее о сайтеГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ... Читать ещёГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. Другое 5 часов назад. Беглов: реконструкция в Таврическом саду Петербурга может обойтись в 2-4 млрд рублей. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ польской. Другое 14 часов назад. ОСК и структуры «Газпрома» и «Газпром нефти» договорились о сотрудничестве. Скрыть
#
#
#
#
#
# 5Газпром сегодня: свежие новости от Газпромnews.rambler.ru›organization/gazprom/ПожаловатьсяИнформация о сайте Подробнее о сайтеГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ... Читать ещёГазпром — все новости. 46 место. Рейтинг организаций Рамблер/новости. Другое 5 часов назад. Беглов: реконструкция в Таврическом саду Петербурга может обойтись в 2-4 млрд рублей. ... «Это сговор»: россияне оценили ситуацию с отказом Польши от поставок «Газпрома». В этот раз им был задан следующий вопрос: «С чем связан отказ
 любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Разумеется. Однако никакие претензии к "Газпрому" невозможны – если нет договора о транзите, то что может делать "Газпром"? Скрыть
#
#
#
#
#
# "Нафтогазовое упорство". Кто пострадает от украинских...baltnews.lt›Новости›…-Naftogaz-iski-Russia…Сохранённая копияПожаловатьсяИнформация о сайтеВ любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Читать ещёВ любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Разумеется. Однако никакие претензии к "Газпрому" невозможны – если нет договора о транзите, то что может делать "Газпром"? Скрыть
#
#
# "Нафтогазовое упорство". Кто пострадает от украинских...
# baltnews.lt›Новости›…-Naftogaz-iski-Russia…Сохранённая копияПожаловатьсяИнформация о сайте
# baltnews.lt›Новости›…-Naftogaz-iski-Russia…
# Сохранённая копияПожаловатьсяИнформация о сайте
# Сохранённая копияПожаловатьсяИнформация о сайте
# В любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Читать ещёВ любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Разумеется. Однако никакие претензии к "Газпрому" невозможны – если нет договора о транзите, то что может делать "Газпром"? Скрыть
# В любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Читать ещёВ любом случае 1 января 2020 года возникнет совершенно очевидная ситуация, при которой "Газпром" не сможет поставлять газ через ГТСУ при всем своем желании: нет договора – нет поставок. Пострадают европейские потребители? Разумеется. Однако никакие претензии к "Газпрому" невозможны – если нет договора о транзите, то что может делать "Газпром"? Скрыть
# Поиск по похожим запросамситуация с газпромом на сегодняситуация с газпромом в самареситуация с газпромом и нафтогазом
#
#
# ситуация с газпромом на сегодняситуация с газпромом в самаре
# ситуация с газпромом на сегодня
# ситуация с газпромом в самаре
# ситуация с газпромом и нафтогазом
# ситуация с газпромом и нафтогазом
#
# 12345дальше
# BingGoogleMail.ru
# BingGoogleMail.ru
# .entity-search{word-wrap:break-word;overflow-wrap:break-word}.entity-search__about-author{color:#999}.entity-search__header-wrapper .entity-search__figures:first-of-type{margin-top:0;position:relative;z-index:1}.entity-search__header-wrapper .entity-search__figures:last-child{position:static}.entity-search__subtitle{line-height:20px}.entity-search__subtitle .label{vertical-align:top}.entity-search__header .entity-search__title+.entity-search__subtitle{margin-top:5px}.entity-search__list .showcase{margin-top:8px}.entity-search__clear{clear:both}.entity-search__description .serp-title{margin-bottom:4px}.entity-search__afisha-schedule{margin:15px 0}.entity-search__afisha-title{display:inline-block}.entity-search__afisha:not(:last-child)::after{display:block;clear:both;margin:20px 0;content:'';border-top:1px solid rgba(0,0,0,.1)}.entity-search_new-view .entity-search__badge,.entity-search_new-view .entity-search__figures{margin-top:20px}.entity-search_new-view .entity-search__buttons{margin-bottom:20px}.entity-search__sites{margin-top:10px;margin-right:-8px;overflow:hidden}.entity-search__sites .entity-search__site{margin-top:10px;margin-right:8px}.entity-search__sites .entity-search__site .icon{margin-bottom:-3px;background-size:16px;border-radius:2px}.entity-search__sites .entity-search__site .icon:after{content:none}.entity-search__about-text{margin:8px 0}.tabs-panes__pane .entity-search__card-wrapper .entity-search__badge:first-child{margin-top:0}.entity-search .tabs-panes__pane{margin-top:20px}.entity-search .tabs-panes__pane .ugc{margin-bottom:20px}.entity-search__clear+.entity-search__ugc{margin-top:26px}.entity-search__card-wrapper_only-thumb_yes .entity-search__badge{margin-top:0}.content__right_cols_6 .entity-search__title,.content__right_cols_8 .entity-search__title{font-size:24px;line-height:28px}.entity-search__subtitle .label{margin-top:2px}.entity-search__about,.entity-search__badge,.entity-search__cinema,.entity-search__figures,.entity-search__header+.entity-search__ugc,.entity-search__homonyms:not(:first-child),.entity-search__list:not(:first-child){margin-top:26px}.entity-search__soap{margin-top:-14px;margin-bottom:26px}.entity-search__buttons{margin-bottom:26px}.entity-search__facts-wrapper{margin-top:10px}.entity-search__geo-actions{margin-bottom:10px}.entity-search__sites{max-height:92px}.object-figures .image{max-width:none}.object-figures__buy-panel{margin-top:10px}.content__right_cols_6 .object-figures__buy-panel+.object-figures__poster,.content__right_cols_8 .object-figures__buy-panel+.object-figures__poster,.page-layout__right_cols_6 .object-figures__buy-panel+.object-figures__poster,.page-layout__right_cols_8 .object-figures__buy-panel+.object-figures__poster{bottom:52px}.object-figures_with-map .gallery__main:last-child{min-width:100%}.object-figures_with-map .gallery__main:last-child .gallery__row{display:-webkit-flex;display:-ms-flexbox;display:flex}.object-figures_with-map .gallery__main:last-child .map2{-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1}.object-figures_type_gallery .gallery__main .map2:before{position:absolute;left:0;right:0;top:0;bottom:0;border-radius:4px;box-shadow:inset 0 0 0 1px rgba(0,0,0,.05);content:''}.object-figures_type_gallery .gallery__main .map2 .thumb{position:absolute;bottom:10px;left:10px;background-color:#fff;box-shadow:0 4px 8px rgba(0,0,0,.25)}.object-figures_type_gallery .gallery__main .image{max-width:200px}.content__right_cols_6 .object-figures_type_gallery .gallery__main .image,.content__right_cols_8 .object-figures_type_gallery .gallery__main .image{max-width:150px}.object-figures_type_gallery .gallery__main .video2 .image{max-width:none}.object-figures_type_gallery .gallery__main .map2{width:320px}.object-figures_type_gallery .gallery__main .map2 .thumb__image{height:53px}@media (max-width:1150px){.object-figures_type_gallery .gallery__main .map2{width:240px}.object-figures_type_gallery .gallery__main .map2 .thumb__image{height:40px}}.object-figures_type_m ...
# ГазпромРоссийская компанияВикипедияРоссийская энергетическая компания, более 50% акций которой принадлежит государству. Является холдинговой компанией Группы «Газпром». Непосредственно ПАО «Газпром» осуществляет только продажу природного газа и сдаёт в аренду свою газотранспортную систему. Основные направления деятельности - геологоразведка, добыча, транспортировка, хранение, переработка и реализация газа, газового конденсата и нефти, реализация газа в качестве моторного топлива, а также производство и сбыт тепло- и электроэнергии. Читать дальшеДата основания: 1990 г.Ключевые фигуры: Алексей Миллер, Виктор ЗубковКоличество сотрудников: 26 653 (2018 г.)ВикипедияСообщить об ошибке
# ГазпромРоссийская компанияВикипедияРоссийская энергетическая компания, более 50% акций которой принадлежит государству. Является холдинговой компанией Группы «Газпром». Непосредственно ПАО «Газпром» осуществляет только продажу природного газа и сдаёт в аренду свою газотранспортную систему. Основные направления деятельности - геологоразведка, добыча, транспортировка, хранение, переработка и реализация газа, газового конденсата и нефти, реализация газа в качестве моторного топлива, а также производство и сбыт тепло- и электроэнергии. Читать дальшеДата основания: 1990 г.Ключевые фигуры: Алексей Миллер, Виктор ЗубковКоличество сотрудников: 26 653 (2018 г.)ВикипедияСообщить об ошибке
# ГазпромРоссийская компанияВикипедияРоссийская энергетическая компания, более 50% акций которой принадлежит государству. Является холдинговой компанией Группы «Газпром». Непосредственно ПАО «Газпром» осуществляет только продажу природного газа и сдаёт в аренду свою газотранспортную систему. Основные направления деятельности - геологоразведка, добыча, транспортировка, хранение, переработка и реализация газа, газового конденсата и нефти, реализация газа в качестве моторного топлива, а также производство и сбыт тепло- и электроэнергии. Читать дальшеДата основания: 1990 г.Ключевые фигуры: Алексей Миллер, Виктор ЗубковКоличество сотрудников: 26 653 (2018 г.)ВикипедияСообщить об ошибке
# ГазпромРоссийская компания
#
#
#
#
#
#
# ГазпромРоссийская компания
# Газпром
# Российская компания
# ВикипедияРоссийская энергетическая компания, более 50% акций которой принадлежит государству. Является холдинговой компанией Группы «Газпром». Непосредственно ПАО «Газпром» осуществляет только продажу природного газа и сдаёт в аренду свою газотранспортную систему. Основные направления деятельности - геологоразведка, добыча, транспортировка, хранение, переработка и реализация газа, газового конденсата и нефти, реализация газа в качестве моторного топлива, а также производство и сбыт тепло- и электроэнергии. Читать дальшеДата основания: 1990 г.Ключевые фигуры: Алексей Миллер, Виктор ЗубковКоличество сотрудников: 26 653 (2018 г.)
# ВикипедияРоссийская энергетическая компания, более 50% акций которой принадлежит государству. Является холдинговой компанией Группы «Газпром». Непосредственно ПАО «Газпром» осуществляет только продажу природного газа и сдаёт в аренду свою газотранспортную систему. Основные направления деятельности - геологоразведка, добыча, транспортировка, хранение, переработка и реализация газа, газового конденсата и нефти, реализация газа в качестве моторного топлива, а также производство и сбыт тепло- и электроэнергии. Читать дальше
# Википедия
# Дата основания: 1990 г.Ключевые фигуры: Алексей Миллер, Виктор ЗубковКоличество сотрудников: 26 653 (2018 г.)
#
# ВикипедияСообщить об ошибке
# ВикипедияСообщить об ошибке
# Нашлось 2 млн результатов29 показов в месяцДать объявление
#
# Нашлось 2 млн результатов
# 29 показов в месяц
# Дать объявление
#
# РегистрацияВойтиВойдите через соцcеть
# Войдите через соцcеть
# Войдите через соцcеть
# Войдите через соцcеть
# Войдите через соцcеть
#
#
#
#
#
# Попробовать ещё раз
# Попробовать ещё раз
#
#
# МоскваНастройкиКлавиатураПомощьОбратная связьДля бизнесаДиректМетрикаКассаТелефонияДля душиМузыкаПогодаЭфирКоллекцииЯндексО компанииВакансииБлогКонтактыМобильный поиск© 1997–2019  ООО «Яндекс»Лицензия на поискСтатистикаПоиск защищён технологией ProtectПриложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+СкачатьБудьте в Плюсе
#
# МоскваНастройкиКлавиатураПомощьОбратная связь
# МоскваНастройкиКлавиатураПомощьОбратная связь
# Для бизнесаДиректМетрикаКассаТелефонияДля душиМузыкаПогодаЭфирКоллекцииЯндексО компанииВакансииБлогКонтактыМобильный поиск© 1997–2019  ООО «Яндекс»Лицензия на поискСтатистикаПоиск защищён технологией ProtectПриложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
# Для бизнесаДиректМетрикаКассаТелефонияДля душиМузыкаПогодаЭфирКоллекцииЯндексО компанииВакансииБлогКонтактыМобильный поиск© 1997–2019  ООО «Яндекс»Лицензия на поискСтатистикаПоиск защищён технологией ProtectПриложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
# Для бизнесаДиректМетрикаКассаТелефонияДля душиМузыкаПогодаЭфирКоллекцииЯндексО компанииВакансииБлогКонтактыМобильный поиск© 1997–2019  ООО «Яндекс»Лицензия на поискСтатистикаПоиск защищён технологией Protect
# Для бизнесаДиректМетрикаКассаТелефонияДля душиМузыкаПогодаЭфирКоллекцииЯндексО компанииВакансииБлогКонтакты
# Для бизнесаДиректМетрикаКассаТелефония
# Для душиМузыкаПогодаЭфирКоллекции
# ЯндексО компанииВакансииБлогКонтакты
# Мобильный поиск
# © 1997–2019  ООО «Яндекс»Лицензия на поискСтатистикаПоиск защищён технологией Protect
# © 1997–2019  ООО «Яндекс»Лицензия на поискСтатистика
# © 1997–2019  ООО «Яндекс»
# Поиск защищён технологией Protect
# Приложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
# Приложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
# Приложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
#
#
#
#
# Приложение Яндекс.ТаксиСпособ оплаты можно поменять уже в пути0+Скачать
# Приложение Яндекс.Такси
# Способ оплаты можно поменять уже в пути0+
# Будьте в Плюсе

# %%
def get_html(url):
    r = requests.get(url)
    return r.text
def get_total_pages(html):
    soup = BeautifulSoup(html, 'lxml')
    pages = soup.find('div', class_='search-result-paging').find_all('a')
    total_pages = pages[-2].get('href').split('/')[-2]
    return int(total_pages)
def get_page_data(html):
    soup = BeautifulSoup(html, 'lxml')
    ads = soup.find('div', class_='main-wrap__content').find_all('div', class_='company-item')
    spisok = []
    for ad in ads:
        
        try:
            title = ad.find('div', class_='company-item__title').find('a').text.strip()
        except:
            title = ''
        try:
            url = 'https://www.rusprofile.ru'+str(ad.find('div', class_='company-item__title').find('a').get('href'))
        except:
            url = ''
        try:
            address = ad.find('address').text.strip()
        except:
            address = ''
        ad_subs = ad.find_all('div', class_='company-item-info')
        try:
            manager = ad_subs[0].find('dt').text
        except:
            manager = ''
        try:
            manager_name = ad_subs[0].find('dd').text
        except:
            manager_name = ''
        try:
            INN = ad_subs[1].find('dt').text
        except:
            INN = ''
        try:
            INN_value = ad_subs[1].find('dd').text
        except:
            INN_value = ''
        try:
            dealing = ad_subs[2].find('dt').text
        except:
            dealing = ''
        try:
            okved = ad_subs[2].find('dd').text
        except:
            okved = ''
        

        data = {'Название компании': title, 'URL-адрес': url,
               'Адрес': address, 'Руководитель': manager,
                'ФИО руководителя': manager_name,
                'Идентификатор': INN, 'ИНН': INN_value,
                'Вид деятельности': dealing, 'ОКВЭД': okved}
        spisok.append(data)
        
        
    return spisok

# %%
def main():
    url = 'https://www.rusprofile.ru/codes/683210/moskva'
    base_url = 'https://www.rusprofile.ru/codes/683210/moskva/'
    total_pages = get_total_pages(get_html(url))
    spisok = []
    for i in range(3, total_pages-1):
        url_gen = base_url + str(i)
        html = get_html(url_gen)
        spisok.extend(get_page_data(html))
    return spisok

# %%
okved_683210_moskva = pd.DataFrame(main())
#okved_683210_moskva.to_excel('okved_683210_moskva.xlsx')

# %%
okved_683210_moskva = pd.read_excel('okved_683210_moskva.xlsx')

# %%
urls = okved_683210_moskva['URL-адрес']

# %%
import time
spisok = []
for url in urls:
    time.sleep(2)
    html = get_html(url)
    soup = BeautifulSoup(html, 'lxml')
    try:
        ads = ''
        ads = soup.find_all('div', class_='change-item')
        if len(ads) > 1:
            for ad in ads:
                date_change = ''
                text_change = ''
                date_change = ad.find('div', class_='change-item__date').text
                text_change = ad.find('div', class_='change-item__text').text.strip()
                data = {'URL-адрес': url, 'Дата изменений': date_change, 'Текст изменений': text_change}
                spisok.append(data)
    except:
        pass
changes_in_okved_683210_moskva = pd.DataFrame(spisok)
changes_in_okved_683210_moskva.to_excel('changes_in_okved_683210_moskva.xlsx')

# %% [markdown]
# # Читаю по парсингу на https://habr.com/ru/company/ods/blog/346632/

# %%
page_link = 'http://knowyourmeme.com/memes/all/page/1'
#page_link = 'https://www.rusprofile.ru/codes/683210/moskva'

response = requests.get(page_link)
response
# Out:
# <Response [403]>

# %%
for key, value in response.request.headers.items():
    print(key+": "+value)
# Out:
# User-Agent: python-requests/2.22.0
# Accept-Encoding: gzip, deflate
# Accept: */*
# Connection: keep-alive

# %%
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.2 Safari/537.36'

# %%
response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
response
# Out:
# <Response [200]>

# %%
html = response.text
html[:1000]
# Out:
# '<!DOCTYPE html>\n<html xmlns:fb=\'https://www.facebook.com/2008/fbml\' xmlns=\'https://www.w3.org/1999/xhtml\'>\n<head>\n<meta content=\'text/html; charset=utf-8\' http-equiv=\'Content-Type\'>\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"c1a6d52f38","applicationID":"31165848","transactionName":"dFdfRUpeWglTQB8GDUNKWFRLHlcJWg==","queueTime":0,"applicationTime":115,"agent":""}</script>\n<script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("trace'

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
soup.html.head.title.text
# Out:
# 'All Entries | Know Your Meme'

# %%
obj = soup.find(lambda tag: tag.name == 'a' and tag.get('class') == ['photo'])
obj
# Out:
# <a class="photo" href="/memes/8-mile-rap-battle"><img alt="8 Mile Rap Battle" data-src="https://i.kym-cdn.com/entries/icons/medium/000/031/011/cover4.jpg" src="https://s.kym-cdn.com/assets/blank-b3f96f160b75b1b49b426754ba188fe8.gif" title="8 Mile Rap Battle"/> <div class="entry-labels"> <span class="label label-submission"> Submission </span> </div> </a>

# %%
obj.attrs['href']
# Out:
# '/memes/8-mile-rap-battle'

# %%
meme_links = soup.findAll(lambda tag: tag.name == 'a' and tag.get('class') == ['photo'])
meme_links[:3]
# Out:
# [<a class="photo" href="/memes/8-mile-rap-battle"><img alt="8 Mile Rap Battle" data-src="https://i.kym-cdn.com/entries/icons/medium/000/031/011/cover4.jpg" src="https://s.kym-cdn.com/assets/blank-b3f96f160b75b1b49b426754ba188fe8.gif" title="8 Mile Rap Battle"/> <div class="entry-labels"> <span class="label label-submission"> Submission </span> </div> </a>,
#  <a class="photo" href="/memes/jacob-rees-mogg-lying-down-in-the-commons"><img alt="Jacob Rees-Mogg Lying Down In The Commons" data-src="https://i.kym-cdn.com/entries/icons/medium/000/031/010/Screenshot_2019-09-04_at_1.11.07_PM.png" src="https://s.kym-cdn.com/assets/blank-b3f96f160b75b1b49b426754ba188fe8.gif" title="Jacob Rees-Mogg Lying Down In The Commons"/> <div class="entry-labels"> <span class="label label-submission"> Submission </span> </div> </a>,
#  <a class="photo" href="/memes/spirituality-definition-the-true-inner-meaning"><img alt="spirituality definition the true inner meaning" data-src="https://i.kym-cdn.com/entries/icons/medium/000/031/009/ggggg.jpg" src="https://s.kym-cdn.com/assets/blank-b3f96f160b75b1b49b426754ba188fe8.gif" title="spirituality definition the true inner meaning"/> <div class="entry-labels"> <span class="label label-submission"> Submission </span> </div> </a>]

# %%
meme_links = [link.attrs['href'] for link in meme_links]
meme_links[:10]
# Out:
# ['/memes/8-mile-rap-battle',
#  '/memes/jacob-rees-mogg-lying-down-in-the-commons',
#  '/memes/spirituality-definition-the-true-inner-meaning',
#  '/memes/thomas-had-never-seen-such-bullshit-before',
#  '/memes/geedis-and-the-land-of-ta',
#  '/memes/sites/zao',
#  '/memes/events/forever-21-bankruptcy',
#  '/memes/subcultures/spirit-halloween',
#  '/memes/mike-wazowski-sulley-face-swap',
#  '/memes/depression-blue-body-scan']

# %%
def getPageLinks(page_number):
    """
        Возвращает список ссылок на мемы, полученный с текущей страницы

        page_number: int/string
            номер страницы для парсинга

    """
    # составляем ссылку на страницу поиска
    page_link = 'http://knowyourmeme.com/memes/all/page/{}'.format(page_number)

    # запрашиваем данные по ней
    response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})

    if not response.ok:
        # если сервер нам отказал, вернем пустой лист для текущей страницы
        return []

    # получаем содержимое страницы и переводим в суп
    html = response.content
    soup = BeautifulSoup(html,'html.parser')

    # наконец, ищем ссылки на мемы и очищаем их от ненужных тэгов
    meme_links = soup.findAll(lambda tag: tag.name == 'a' and tag.get('class') == ['photo'])
    meme_links = ['http://knowyourmeme.com' + link.attrs['href'] for link in meme_links]

    return meme_links

# %%
def checkIP():
    ip = requests.get('http://checkip.dyndns.org').content
    soup = BeautifulSoup(ip, 'html.parser')
    print(soup.find('body').text)

checkIP()
# Out:
# Current IP Address: 178.18.212.84

# %%
# !pip3 install PySocks
# Out:
# Collecting PySocks
#   Downloading https://files.pythonhosted.org/packages/cd/18/102cc70347486e75235a29a6543f002cf758042189cb063ec25334993e36/PySocks-1.7.0-py3-none-any.whl
# Installing collected packages: PySocks
# Successfully installed PySocks-1.7.0
# WARNING: You are using pip version 19.2.1, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import PySocks
import socket
PySocks.set_default_proxy(PySocks.SOCKS5, "localhost", 9150)
socket.socket = PySocks.socksocket
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-deff65426f86> in <module>
# ----> 1 import PySocks
#       2 import socket
#       3 PySocks.set_default_proxy(PySocks.SOCKS5, "localhost", 9150)
#       4 socket.socket = PySocks.socksocket
#
# ModuleNotFoundError: No module named 'PySocks'

# %%
import PySocks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-18f705450848> in <module>
# ----> 1 import PySocks
#
# ModuleNotFoundError: No module named 'PySocks'
